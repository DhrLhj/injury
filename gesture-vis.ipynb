# %%
import glob

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from util.dataloader import get_templates, norm_pose

# %%
file_path = sorted(glob.glob('data/*.csv'))[-1]

# file_path = "data/mppose_1694226374.csv"
pd_1 = pd.read_csv(open(file_path))
arr_coords = pd_1.values.reshape(-1,6,3) #
arr_coords_norm = np.array(list(map(norm_pose,arr_coords)))
# arr_coords_norm = arr_coords_norm[1:] - arr_coords_norm[:-1]

# %%
N = 30
weights = np.ones(N)/N

# %%
arr_coords_norm[30:].shape
# Out:
# (785, 2, 3)

# %%
res = np.sqrt(((arr_coords_norm[30:,:,:] - arr_coords_norm[:-30,:,:])**2).sum(axis=2))

# %%
plt.plot(res[:,0])
plt.show()

# %%
res[0]
# Out:
# array([1.68909708, 1.65378643])

# %%
if 0.0:
    print(1)

# %%
sum([1 if a >= 2 else 0 for a in res[0]])
# Out:
# 0

# %%
8&0
# Out:
# 0

# %%
res[]
# Out:
# array([[1.68909708, 1.65378643],
#        [1.49891178, 1.72474383],
#        [1.33084327, 1.64595306],
#        ...,
#        [0.37962243, 1.42081499],
#        [0.19046685, 1.28526519],
#        [0.16445601, 1.29386448]])

# %% [markdown]
# ## 模板

# %%
for file_path in glob.glob('gesture_template/0908/*.csv'):

    # file_path = "data/mppose_1694226374.csv"
    pd_1 = pd.read_csv(open(file_path))
    arr_coords = pd_1.values.reshape(-1,6,3) #
#     arr_coords_norm = np.array(list(map(norm_pose,arr_coords)))
    plt.figure()
    x = arr_coords[:,0,0].flatten()
    y = arr_coords[:,0,1].flatten()
    plt.plot(x,y)
    x = arr_coords[:,1,0].flatten()
    y = arr_coords[:,1,1].flatten()
    # x = x+0.4
    plt.plot(x,y)
    plt.show()

# %%
for file_path in glob.glob('gesture_template/0908/*.csv'):

    # file_path = "data/mppose_1694226374.csv"
    pd_1 = pd.read_csv(open(file_path))
    arr_coords = pd_1.values.reshape(-1,6,3) #
    arr_coords_norm = np.array(list(map(norm_pose,arr_coords)))
    plt.figure()
    x = arr_coords_norm[:,0,0].flatten()
    y = arr_coords_norm[:,0,1].flatten()
    plt.plot(x,y)
    x = arr_coords_norm[:,1,0].flatten()
    y = arr_coords_norm[:,1,1].flatten()
    # x = x+0.4
    plt.plot(x,y)
    plt.show()

# %% [markdown]
# ## 手部水平左右移动

# %%
x = arr_coords_norm[:,0,0].flatten()
y = arr_coords_norm[:,0,1].flatten()
plt.plot(x,y,'r')
x = arr_coords_norm[:,1,0].flatten()
y = arr_coords_norm[:,1,1].flatten()
# x = x+0.4
plt.plot(x,y,'b')
plt.show()

# %% [markdown]
# ## 手部垂直上下移动

# %%
x = arr_coords_norm[:,0,0].flatten()
y = arr_coords_norm[:,0,1].flatten()
plt.plot(x,y)
x = arr_coords_norm[:,1,0].flatten()
y = arr_coords_norm[:,1,1].flatten()
# x = x+0.4
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 雪元随便动的手部轨迹

# %%
x = arr_coords_norm[:,0,0].flatten()
y = arr_coords_norm[:,0,1].flatten()
plt.plot(x,y)
x = arr_coords_norm[:,1,0].flatten()
y = arr_coords_norm[:,1,1].flatten()
x = x+0.4
plt.plot(x,y)
plt.show()

# %%
x = arr_coords_norm[:,0,0].flatten()
y = arr_coords_norm[:,0,1].flatten()
plt.plot(x,y)
x = arr_coords_norm[:,1,0].flatten()
y = arr_coords_norm[:,1,1].flatten()
x = x+0.4
plt.plot(x,y)
plt.show()

# %%
x = arr_coords_norm[:,0,0].flatten()
y = arr_coords_norm[:,0,1].flatten()
plt.plot(x,y)
x = arr_coords_norm[:,1,0].flatten()
y = arr_coords_norm[:,1,1].flatten()
x = x+0.4
plt.plot(x,y)
plt.show()

# %%
arr_coords_norm.shape
# Out:
# (781, 2, 3)

# %%
temp, template_dynamic_gesture = get_templates("gesture_template/0907")
